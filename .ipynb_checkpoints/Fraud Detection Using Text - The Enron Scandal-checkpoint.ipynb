# %% [markdown]
# # Fraud Detection Using Text - The Enron Scandal

# %% [markdown]
# ## Welcome

# %% [markdown]
# ## Dataset description

# %% [markdown]
# ## Important libraries

# %%
# pandas & numpy:
import numpy as np
import pandas as pd

# visualization:
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud, STOPWORDS
import plotly.express as px

# tokenization:
import re
import nltk
from nltk.stem import PorterStemmer, WordNetLemmatizer
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.stem.porter import PorterStemmer
import string

# gensim:
import gensim
from gensim.utils import simple_preprocess
from gensim.parsing.preprocessing import STOPWORDS

# scikit-learn:
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report
from sklearn.metrics import confusion_matrix
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV


#keras:
from tensorflow.keras.preprocessing.text import one_hot, Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences #We use this because some text are shorter than others. All text should have the same number of words

# %% [markdown]
# ## Loading & understanding our data

# %%
df=pd.read_csv('Data/emails_cleaned.csv')
# With "pd.set_option('display.max_columns', None)" we see all the columns of the dataset.
pd.set_option('display.max_columns', None)
df.head()
# Out:
#                        file  \
# 0     allen-p/_sent_mail/1.
# 1    allen-p/_sent_mail/10.
# 2   allen-p/_sent_mail/100.
# 3  allen-p/_sent_mail/1000.
# 4  allen-p/_sent_mail/1001.
#
#                                              message  \
# 0  Message-ID: <18782981.1075855378110.JavaMail.e...
# 1  Message-ID: <15464986.1075855378456.JavaMail.e...
# 2  Message-ID: <24216240.1075855687451.JavaMail.e...
# 3  Message-ID: <13505866.1075863688222.JavaMail.e...
# 4  Message-ID: <30922949.1075863688243.JavaMail.e...
#
#                                              content  \
# 0                          Here is our forecast\n\n
# 1  Traveling to have a business meeting takes the...
# 2                     test successful.  way to go!!!
# 3  Randy,\n\n Can you send me a schedule of the s...
# 4                Let's shoot for Tuesday at 11:45.
#
#                                      Message-ID  \
# 0  <18782981.1075855378110.JavaMail.evans@thyme
# 1  <15464986.1075855378456.JavaMail.evans@thyme
# 2  <24216240.1075855687451.JavaMail.evans@thyme
# 3  <13505866.1075863688222.JavaMail.evans@thyme
# 4  <30922949.1075863688243.JavaMail.evans@thyme
#
#                                    Date                    From  \
# 0  Mon, 14 May 2001 16:39:00 -0700 (PDT  phillip.allen@enron.co
# 1   Fri, 4 May 2001 13:51:00 -0700 (PDT  phillip.allen@enron.co
# 2  Wed, 18 Oct 2000 03:00:00 -0700 (PDT  phillip.allen@enron.co
# 3  Mon, 23 Oct 2000 06:13:00 -0700 (PDT  phillip.allen@enron.co
# 4  Thu, 31 Aug 2000 05:07:00 -0700 (PDT  phillip.allen@enron.co
#
#                        To   Subject   Cc  Mime-Version  \
# 0     tim.belden@enron.co       NaN  NaN           1.0
# 1  john.lavorato@enron.co        Re  NaN           1.0
# 2   leah.arsdall@enron.co   Re: tes  NaN           1.0
# 3    randall.gay@enron.co       NaN  NaN           1.0
# 4     greg.piper@enron.co  Re: Hell  NaN           1.0
#
#                   Content-Type Content-Transfer-Encoding  Bcc          X-From  \
# 0  text/plain; charset=us-asci                       7bi  NaN  Phillip K Alle
# 1  text/plain; charset=us-asci                       7bi  NaN  Phillip K Alle
# 2  text/plain; charset=us-asci                       7bi  NaN  Phillip K Alle
# 3  text/plain; charset=us-asci                       7bi  NaN  Phillip K Alle
# 4  text/plain; charset=us-asci                       7bi  NaN  Phillip K Alle
#
#                                                 X-To X-cc X-bcc  \
# 0            Tim Belden <Tim Belden/Enron@EnronXGate  NaN   NaN
# 1  John J Lavorato <John J Lavorato/ENRON@enronXg...  NaN   NaN
# 2                                    Leah Van Arsdal  NaN   NaN
# 3                                       Randall L Ga  NaN   NaN
# 4                                          Greg Pipe  NaN   NaN
#
#                                             X-Folder X-Origin  \
# 0  \Phillip_Allen_Jan2002_1\Allen, Phillip K.\'Se...   Allen-
# 1  \Phillip_Allen_Jan2002_1\Allen, Phillip K.\'Se...   Allen-
# 2     \Phillip_Allen_Dec2000\Notes Folders\'sent mai   Allen-
# 3     \Phillip_Allen_Dec2000\Notes Folders\'sent mai   Allen-
# 4     \Phillip_Allen_Dec2000\Notes Folders\'sent mai   Allen-
#
#                     X-FileName  has_other_content  if_forwarded
# 0  pallen (Non-Privileged).pst              False         False
# 1  pallen (Non-Privileged).pst              False         False
# 2                   pallen.nsf              False         False
# 3                   pallen.nsf              False         False
# 4                   pallen.nsf              False         False

# %%
def clean_data(df):
    
    df=df.drop(columns=['file', 'message', 'Cc', 'Mime-Version', 'Content-Type','Content-Transfer-Encoding','Date',
                        'Bcc', 'X-From', 'X-To', 'X-cc', 'X-bcc','X-Folder', 'X-Origin', 'X-FileName', 'has_other_content', 'if_forwarded'])
    df.columns=[e.lower().replace(' ', '_') for e in df.columns]
    
    return df

# %%
df=clean_data(df)
df
# Out:
#                                                   content  \
# 0                               Here is our forecast\n\n
# 1       Traveling to have a business meeting takes the...
# 2                          test successful.  way to go!!!
# 3       Randy,\n\n Can you send me a schedule of the s...
# 4                     Let's shoot for Tuesday at 11:45.
# ...                                                   ...
# 517392  This is a trade with OIL-SPEC-HEDGE-NG (John L...
# 517393  Some of my position is with the Alberta Term b...
# 517394  2\n\n -----Original Message-----\nFrom: \tDouc...
# 517395  Analyst\t\t\t\t\tRank\n\nStephane Brodeur\t\t\...
# 517396  i think the YMCA has a class that is for peopl...
#
#                                           message-id                    from  \
# 0       <18782981.1075855378110.JavaMail.evans@thyme  phillip.allen@enron.co
# 1       <15464986.1075855378456.JavaMail.evans@thyme  phillip.allen@enron.co
# 2       <24216240.1075855687451.JavaMail.evans@thyme  phillip.allen@enron.co
# 3       <13505866.1075863688222.JavaMail.evans@thyme  phillip.allen@enron.co
# 4       <30922949.1075863688243.JavaMail.evans@thyme  phillip.allen@enron.co
# ...                                              ...                     ...
# 517392  <26807948.1075842029936.JavaMail.evans@thyme  john.zufferli@enron.co
# 517393  <25835861.1075842029959.JavaMail.evans@thyme  john.zufferli@enron.co
# 517394  <28979867.1075842029988.JavaMail.evans@thyme  john.zufferli@enron.co
# 517395  <22052556.1075842030013.JavaMail.evans@thyme  john.zufferli@enron.co
# 517396  <28618979.1075842030037.JavaMail.evans@thyme  john.zufferli@enron.co
#
#                                to                   subject
# 0             tim.belden@enron.co                       NaN
# 1          john.lavorato@enron.co                        Re
# 2           leah.arsdall@enron.co                   Re: tes
# 3            randall.gay@enron.co                       NaN
# 4             greg.piper@enron.co                  Re: Hell
# ...                           ...                       ...
# 517392        kori.loibl@enron.co   Trade with John Lavorat
# 517393     john.lavorato@enron.co                 Gas Hedge
# 517394       dawn.doucet@enron.co           RE: CONFIDENTIA
# 517395      jeanie.slone@enron.co  Calgary Analyst/Associat
# 517396  livia_zufferli@monitor.co           RE: ali's essay
#
# [517397 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 517397 entries, 0 to 517396
# Data columns (total 5 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   content     491133 non-null  object
#  1   message-id  517397 non-null  object
#  2   from        517397 non-null  object
#  3   to          495552 non-null  object
#  4   subject     498118 non-null  object
# dtypes: object(5)
# memory usage: 19.7+ MB

# %%
df.isnull().sum()
# Out:
# content       26264
# message-id        0
# from              0
# to            21845
# subject       19279
# dtype: int64

# %%
df=df.dropna().reset_index()
df
# Out:
#          index                                            content  \
# 0            1  Traveling to have a business meeting takes the...
# 1            2                     test successful.  way to go!!!
# 2            4                Let's shoot for Tuesday at 11:45.
# 3            5  Greg,\n\n How about either next Tuesday or Thu...
# 4            7                   any morning between 10 and 11:30
# ...        ...                                                ...
# 451600  517392  This is a trade with OIL-SPEC-HEDGE-NG (John L...
# 451601  517393  Some of my position is with the Alberta Term b...
# 451602  517394  2\n\n -----Original Message-----\nFrom: \tDouc...
# 451603  517395  Analyst\t\t\t\t\tRank\n\nStephane Brodeur\t\t\...
# 451604  517396  i think the YMCA has a class that is for peopl...
#
#                                           message-id                    from  \
# 0       <15464986.1075855378456.JavaMail.evans@thyme  phillip.allen@enron.co
# 1       <24216240.1075855687451.JavaMail.evans@thyme  phillip.allen@enron.co
# 2       <30922949.1075863688243.JavaMail.evans@thyme  phillip.allen@enron.co
# 3       <30965995.1075863688265.JavaMail.evans@thyme  phillip.allen@enron.co
# 4       <17189699.1075863688308.JavaMail.evans@thyme  phillip.allen@enron.co
# ...                                              ...                     ...
# 451600  <26807948.1075842029936.JavaMail.evans@thyme  john.zufferli@enron.co
# 451601  <25835861.1075842029959.JavaMail.evans@thyme  john.zufferli@enron.co
# 451602  <28979867.1075842029988.JavaMail.evans@thyme  john.zufferli@enron.co
# 451603  <22052556.1075842030013.JavaMail.evans@thyme  john.zufferli@enron.co
# 451604  <28618979.1075842030037.JavaMail.evans@thyme  john.zufferli@enron.co
#
#                                to                      subject
# 0          john.lavorato@enron.co                           Re
# 1           leah.arsdall@enron.co                      Re: tes
# 2             greg.piper@enron.co                     Re: Hell
# 3             greg.piper@enron.co                     Re: Hell
# 4         joyce.teixeira@enron.co  Re: PRC review - phone call
# ...                           ...                          ...
# 451600        kori.loibl@enron.co      Trade with John Lavorat
# 451601     john.lavorato@enron.co                    Gas Hedge
# 451602       dawn.doucet@enron.co              RE: CONFIDENTIA
# 451603      jeanie.slone@enron.co     Calgary Analyst/Associat
# 451604  livia_zufferli@monitor.co              RE: ali's essay
#
# [451605 rows x 6 columns]

# %%
#we want to join all text data in one single column.We will create a new column called "completed_text"
df["completed_text"]=df["subject"]+df["content"]

# %%
df
# Out:
#          index                                            content  \
# 0            1  Traveling to have a business meeting takes the...
# 1            2                     test successful.  way to go!!!
# 2            4                Let's shoot for Tuesday at 11:45.
# 3            5  Greg,\n\n How about either next Tuesday or Thu...
# 4            7                   any morning between 10 and 11:30
# ...        ...                                                ...
# 451600  517392  This is a trade with OIL-SPEC-HEDGE-NG (John L...
# 451601  517393  Some of my position is with the Alberta Term b...
# 451602  517394  2\n\n -----Original Message-----\nFrom: \tDouc...
# 451603  517395  Analyst\t\t\t\t\tRank\n\nStephane Brodeur\t\t\...
# 451604  517396  i think the YMCA has a class that is for peopl...
#
#                                           message-id                    from  \
# 0       <15464986.1075855378456.JavaMail.evans@thyme  phillip.allen@enron.co
# 1       <24216240.1075855687451.JavaMail.evans@thyme  phillip.allen@enron.co
# 2       <30922949.1075863688243.JavaMail.evans@thyme  phillip.allen@enron.co
# 3       <30965995.1075863688265.JavaMail.evans@thyme  phillip.allen@enron.co
# 4       <17189699.1075863688308.JavaMail.evans@thyme  phillip.allen@enron.co
# ...                                              ...                     ...
# 451600  <26807948.1075842029936.JavaMail.evans@thyme  john.zufferli@enron.co
# 451601  <25835861.1075842029959.JavaMail.evans@thyme  john.zufferli@enron.co
# 451602  <28979867.1075842029988.JavaMail.evans@thyme  john.zufferli@enron.co
# 451603  <22052556.1075842030013.JavaMail.evans@thyme  john.zufferli@enron.co
# 451604  <28618979.1075842030037.JavaMail.evans@thyme  john.zufferli@enron.co
#
#                                to                      subject  \
# 0          john.lavorato@enron.co                           Re
# 1           leah.arsdall@enron.co                      Re: tes
# 2             greg.piper@enron.co                     Re: Hell
# 3             greg.piper@enron.co                     Re: Hell
# 4         joyce.teixeira@enron.co  Re: PRC review - phone call
# ...                           ...                          ...
# 451600        kori.loibl@enron.co      Trade with John Lavorat
# 451601     john.lavorato@enron.co                    Gas Hedge
# 451602       dawn.doucet@enron.co              RE: CONFIDENTIA
# 451603      jeanie.slone@enron.co     Calgary Analyst/Associat
# 451604  livia_zufferli@monitor.co              RE: ali's essay
#
#                                            completed_text
# 0       ReTraveling to have a business meeting takes t...
# 1                   Re: testest successful.  way to go!!!
# 2             Re: HellLet's shoot for Tuesday at 11:45.
# 3       Re: HellGreg,\n\n How about either next Tuesda...
# 4       Re: PRC review - phone callany morning between...
# ...                                                   ...
# 451600  Trade with John LavoratThis is a trade with OI...
# 451601  Gas HedgeSome of my position is with the Alber...
# 451602  RE: CONFIDENTIA2\n\n -----Original Message----...
# 451603  Calgary Analyst/AssociatAnalyst\t\t\t\t\tRank\...
# 451604  RE: ali's essayi think the YMCA has a class th...
#
# [451605 rows x 7 columns]

# %%
# Let's see how looks the first element of the column "completed_text"
df['completed_text'][0]
# Out:
# "ReTraveling to have a business meeting takes the fun out of the trip.  Especially if you have to prepare a presentation.  I would suggest holding the business plan meetings here then take a trip without any formal business meetings.  I would even try and get some honest opinions on whether a trip is even desired or necessary.\n\nAs far as the business meetings, I think it would be more productive to try and stimulate discussions across the different groups about what is working and what is not.  Too often the presenter speaks and the others are quiet just waiting for their turn.   The meetings might be better if held in a round table discussion format.  \n\nMy suggestion for where to go is Austin.  Play golf and rent a ski boat and jet ski's.  Flying somewhere takes too much time.\n"

# %%
# Now that we have joined the columns "subject" and "content" into one column, we can delete them 
df=df.drop(columns=['content', 'subject'],axis=1)

# %% [markdown]
# ## Fraud flags

# %%
# Now that we have all the text data together, we can flag some terms as "fraud suspect"
# WE know that Enron employees activaley participated in the fraud by keeping the stock price manually high. 
# We can create a list of fraudulent terms that helps us to find the emails with reference to the word "stock".

fraud_list=['stock','enron stock','sell stock','bonus','wall street','board','the market','dow jones']

# Now we filter the column completed text using the list "fraud_list".


filtered_emails = df.loc[df['completed_text'].str.contains('|'.join(fraud_list), na=False)]
print(filtered_emails)
# Out:
#          index                                    message-id  \
# 176        381  <21041312.1075855725847.JavaMail.evans@thyme
# 177        390  <10842131.1075855726025.JavaMail.evans@thyme
# 223        505  <10513667.1075855728452.JavaMail.evans@thyme
# 239        543  <23792894.1075855729213.JavaMail.evans@thyme
# 270        602  <29790972.1075855665306.JavaMail.evans@thyme
# ...        ...                                           ...
# 451551  517343   <6198978.1075842028789.JavaMail.evans@thyme
# 451552  517344  <33268729.1075842028813.JavaMail.evans@thyme
# 451553  517345  <30044691.1075842028836.JavaMail.evans@thyme
# 451558  517350   <1444594.1075842028951.JavaMail.evans@thyme
# 451584  517376  <23888524.1075842029528.JavaMail.evans@thyme
#
#                                           from                       to  \
# 176                     phillip.allen@enron.co      kim.bolton@enron.co
# 177                     phillip.allen@enron.co         jacquestc@aol.co
# 223                     phillip.allen@enron.co      ina.rangel@enron.co
# 239                     phillip.allen@enron.co  mac.d.hargrove@rssmb.co
# 270     1.11913372.-2@multexinvestornetwork.co          pallen@enron.co
# ...                                        ...                      ...
# 451551                  john.zufferli@enron.co    chris.lambie@enron.co
# 451552                  john.zufferli@enron.co    chris.lambie@enron.co
# 451553                  john.zufferli@enron.co    chris.lambie@enron.co
# 451558                  john.zufferli@enron.co   garrett.tripp@enron.co
# 451584                  john.zufferli@enron.co         jzufferli@shaw.c
#
#                                            completed_text
# 176     RE: PERSONAL AND CONFIDENTIAL COMPENSATION INF...
# 177     Bishops Corner, Ltd. BuyouJacques,\n\nGeorge f...
# 223                        Re: Please responmessage board
# 239     RE: accesReceived the fax.  Thank you.  I migh...
# 270     December 14, 2000 - Bear Stearns' predictions ...
# ...                                                   ...
# 451551  REWOW, that was higher than I thought.  That i...
# 451552  REi don't even know your salary now.\n\n -----...
# 451553  REI am reading your mail, I have asked for the...
# 451558  RE: Ontario Updatdo you have the internet addr...
# 451584  FW\n\n -----Original Message-----\nFrom: \tLiv...
#
# [26141 rows x 5 columns]

# %%
# "Filtered_emails" represents the emails with fraudulent terminology. 
# We will create a new column named fraud in the dataframe. 
# The new column will have 2 values: 0: non-fraud ; 1: fraud

df['fraud'] = np.where((df['completed_text'].str.contains('|'.join(fraud_list)) == True), 1, 0)
        
df
# Out:
#          index                                    message-id  \
# 0            1  <15464986.1075855378456.JavaMail.evans@thyme
# 1            2  <24216240.1075855687451.JavaMail.evans@thyme
# 2            4  <30922949.1075863688243.JavaMail.evans@thyme
# 3            5  <30965995.1075863688265.JavaMail.evans@thyme
# 4            7  <17189699.1075863688308.JavaMail.evans@thyme
# ...        ...                                           ...
# 451600  517392  <26807948.1075842029936.JavaMail.evans@thyme
# 451601  517393  <25835861.1075842029959.JavaMail.evans@thyme
# 451602  517394  <28979867.1075842029988.JavaMail.evans@thyme
# 451603  517395  <22052556.1075842030013.JavaMail.evans@thyme
# 451604  517396  <28618979.1075842030037.JavaMail.evans@thyme
#
#                           from                         to  \
# 0       phillip.allen@enron.co     john.lavorato@enron.co
# 1       phillip.allen@enron.co      leah.arsdall@enron.co
# 2       phillip.allen@enron.co        greg.piper@enron.co
# 3       phillip.allen@enron.co        greg.piper@enron.co
# 4       phillip.allen@enron.co    joyce.teixeira@enron.co
# ...                        ...                        ...
# 451600  john.zufferli@enron.co        kori.loibl@enron.co
# 451601  john.zufferli@enron.co     john.lavorato@enron.co
# 451602  john.zufferli@enron.co       dawn.doucet@enron.co
# 451603  john.zufferli@enron.co      jeanie.slone@enron.co
# 451604  john.zufferli@enron.co  livia_zufferli@monitor.co
#
#                                            completed_text  fraud
# 0       ReTraveling to have a business meeting takes t...      0
# 1                   Re: testest successful.  way to go!!!      0
# 2             Re: HellLet's shoot for Tuesday at 11:45.        0
# 3       Re: HellGreg,\n\n How about either next Tuesda...      0
# 4       Re: PRC review - phone callany morning between...      0
# ...                                                   ...    ...
# 451600  Trade with John LavoratThis is a trade with OI...      0
# 451601  Gas HedgeSome of my position is with the Alber...      0
# 451602  RE: CONFIDENTIA2\n\n -----Original Message----...      0
# 451603  Calgary Analyst/AssociatAnalyst\t\t\t\t\tRank\...      0
# 451604  RE: ali's essayi think the YMCA has a class th...      0
#
# [451605 rows x 6 columns]

# %%
count = df['fraud'].value_counts()
print(count)
# Out:
# 0    425464
# 1     26141
# Name: fraud, dtype: int64

# %%
#Plot the count plot for fraudulent and no fraudulent emails
plt.figure(figsize = (4, 4))
sns.countplot(y = "fraud", data = df,palette='vlag')
plt.title('Fraud Distributions \n (0:Non_Fraud || 1: Fraud)', fontsize=11)
plt.show()

# %% [markdown]
# ## Detecting fraud using text mining

# %% [markdown]
# In order to clean our text data we need to follow these steps:
#     <ol>
#   <li>Tokenization</li>
#   <li>Remove all Stopwords</li>
#   <li>Lemanize your words</li>
#   <li>Stem your words</li>
# </ol>

# %%
#now he are going to get the stopwords for English
stop_words = list(stopwords.words('english')) 
stop_words
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
#  'down',
#  'in',
#  'out',
#  'on',
#  'off',
#  'over',
#  'under',
#  'again',
#  'further',
#  'then',
#  'once',
#  'here',
#  'there',
#  'when',
#  'where',
#  'why',
#  'how',
#  'all',
#  'any',
#  'both',
#  'each',
#  'few',
#  'more',
#  'most',
#  'other',
#  'some',
#  'such',
#  'no',
#  'nor',
#  'not',
#  'only',
#  'own',
#  'same',
#  'so',
#  'than',
#  'too',
#  'very',
#  's',
#  't',
#  'can',
#  'will',
#  'just',
#  'don',
#  "don't",
#  'should',
#  "should've",
#  'now',
#  'd',
#  'll',
#  'm',
#  'o',
#  're',
#  've',
#  'y',
#  'ain',
#  'aren',
#  "aren't",
#  'couldn',
#  "couldn't",
#  'didn',
#  "didn't",
#  'doesn',
#  "doesn't",
#  'hadn',
#  "hadn't",
#  'hasn',
#  "hasn't",
#  'haven',
#  "haven't",
#  'isn',
#  "isn't",
#  'ma',
#  'mightn',
#  "mightn't",
#  'mustn',
#  "mustn't",
#  'needn',
#  "needn't",
#  'shan',
#  "shan't",
#  'shouldn',
#  "shouldn't",
#  'wasn',
#  "wasn't",
#  'weren',
#  "weren't",
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't"]

# %%
#get additional stop words from nltk
stop_words.extend(['from','to','cc','http', 're', 'www', 'com'])

# %%
# Remove stopwords and remove words with 2 or less characters
def preprocess(text):
    result = []
    for token in gensim.utils.simple_preprocess(text):
        if token not in gensim.parsing.preprocessing.STOPWORDS and len(token) > 3 and token not in stop_words:
            result.append(token)
            
    return result

# %%
# Apply the function to the dataframe
df['clean_text'] = df['completed_text'].apply(preprocess)

# %%
# Now we can compare the columns "completed_text" and "clean_text"
#Show completed_text news
df['completed_text'][0]
# Out:
# "ReTraveling to have a business meeting takes the fun out of the trip.  Especially if you have to prepare a presentation.  I would suggest holding the business plan meetings here then take a trip without any formal business meetings.  I would even try and get some honest opinions on whether a trip is even desired or necessary.\n\nAs far as the business meetings, I think it would be more productive to try and stimulate discussions across the different groups about what is working and what is not.  Too often the presenter speaks and the others are quiet just waiting for their turn.   The meetings might be better if held in a round table discussion format.  \n\nMy suggestion for where to go is Austin.  Play golf and rent a ski boat and jet ski's.  Flying somewhere takes too much time.\n"

# %%
print(df['clean_text'][0])
# Out:
# ['retraveling', 'business', 'meeting', 'takes', 'trip', 'especially', 'prepare', 'presentation', 'suggest', 'holding', 'business', 'plan', 'meetings', 'trip', 'formal', 'business', 'meetings', 'honest', 'opinions', 'trip', 'desired', 'necessary', 'business', 'meetings', 'think', 'productive', 'stimulate', 'discussions', 'different', 'groups', 'working', 'presenter', 'speaks', 'quiet', 'waiting', 'turn', 'meetings', 'better', 'held', 'round', 'table', 'discussion', 'format', 'suggestion', 'austin', 'play', 'golf', 'rent', 'boat', 'flying', 'takes', 'time']

# %%
# Obtain the total words present in the dataset
list_of_words = []
for i in df.clean_text:
    for j in i:
        list_of_words.append(j)

# %%
list_of_words
# Out:
# ['retraveling',
#  'business',
#  'meeting',
#  'takes',
#  'trip',
#  'especially',
#  'prepare',
#  'presentation',
#  'suggest',
#  'holding',
#  'business',
#  'plan',
#  'meetings',
#  'trip',
#  'formal',
#  'business',
#  'meetings',
#  'honest',
#  'opinions',
#  'trip',
#  'desired',
#  'necessary',
#  'business',
#  'meetings',
#  'think',
#  'productive',
#  'stimulate',
#  'discussions',
#  'different',
#  'groups',
#  'working',
#  'presenter',
#  'speaks',
#  'quiet',
#  'waiting',
#  'turn',
#  'meetings',
#  'better',
#  'held',
#  'round',
#  'table',
#  'discussion',
#  'format',
#  'suggestion',
#  'austin',
#  'play',
#  'golf',
#  'rent',
#  'boat',
#  'flying',
#  'takes',
#  'time',
#  'testest',
#  'successful',
#  'helllet',
#  'shoot',
#  'tuesday',
#  'hellgreg',
#  'tuesday',
#  'thursday',
#  'phillip',
#  'review',
#  'phone',
#  'callany',
#  'morning',
#  'high',
#  'speed',
#  'internet',
#  'acces',
#  'login',
#  'pallen',
#  'davis',
#  'think',
#  'required',
#  'static',
#  'address',
#  'gate',
#  'company',
#  'fixed',
#  'forward',
#  'collar',
#  'floor',
#  'price',
#  'termmr',
#  'buckner',
#  'delivered',
#  'diego',
#  'enron',
#  'energy',
#  'services',
#  'appropriate',
#  'enron',
#  'entity',
#  'forwarded',
#  'request',
#  'zarin',
#  'imam',
#  'phone',
#  'number',
#  'phillip',
#  'allen',
#  'margin',
#  'plapaula',
#  'million',
#  'fine',
#  'phillip',
#  'business',
#  'related',
#  'think',
#  'fletch',
#  'good',
#  'original',
#  'sept',
#  'check',
#  'closinbrenda',
#  'second',
#  'check',
#  'october',
#  'payment',
#  'copy',
#  'original',
#  'deal',
#  'want',
#  'phillip',
#  'juan',
#  'indeliane',
#  'discussed',
#  'yesterday',
#  'concerned',
#  'attempt',
#  'manipulate',
#  'paso',
#  'juan',
#  'monthly',
#  'index',
#  'single',
#  'buyer',
#  'entered',
#  'marketplace',
#  'september',
#  'paid',
#  'market',
#  'prices',
#  'juan',
#  'intent',
#  'distort',
#  'index',
#  'time',
#  'trades',
#  'offers',
#  'physical',
#  'significantly',
#  'cents',
#  'lower',
#  'prices',
#  'bypassed',
#  'order',
#  'establish',
#  'higher',
#  'trades',
#  'report',
#  'index',
#  'calculation',
#  'additionally',
#  'trades',
#  'line',
#  'associated',
#  'financial',
#  'swaps',
#  'juan',
#  'compiled',
#  'list',
#  'financial',
#  'physical',
#  'trades',
#  'executed',
#  'september',
#  'september',
#  'complete',
#  'list',
#  'trades',
#  'enron',
#  'online',
#  'enron',
#  'direct',
#  'phone',
#  'conversations',
#  'brokerage',
#  'firms',
#  'amerex',
#  'prebon',
#  'attached',
#  'spreadsheet',
#  'trade',
#  'trade',
#  'list',
#  'summary',
#  'included',
#  'summary',
#  'daily',
#  'prices',
#  'illustrate',
#  'value',
#  'juan',
#  'based',
#  'spread',
#  'relationships',
#  'points',
#  'data',
#  'follows',
#  'high',
#  'physical',
#  'prices',
#  'greater',
#  'high',
#  'financial',
#  'trades',
#  'days',
#  'spread',
#  'relationship',
#  'juan',
#  'points',
#  'socal',
#  'northwest',
#  'consistent',
#  'september',
#  'october',
#  'daily',
#  'sense',
#  'monthly',
#  'indeces',
#  'dramatically',
#  'different',
#  'understand',
#  'review',
#  'trades',
#  'submitted',
#  'outliers',
#  'hopefully',
#  'trades',
#  'submitted',
#  'reveal',
#  'counterparty',
#  'names',
#  'able',
#  'determine',
#  'buyer',
#  'trades',
#  'outliers',
#  'wanted',
#  'additional',
#  'points',
#  'reference',
#  'establishing',
#  'reasonable',
#  'index',
#  'enron',
#  'belief',
#  'trades',
#  'higher',
#  'market',
#  'trades',
#  'excluded',
#  'calculation',
#  'index',
#  'desire',
#  'reliable',
#  'accurate',
#  'indeces',
#  'conduct',
#  'physical',
#  'financial',
#  'business',
#  'contact',
#  'anytime',
#  'assist',
#  'goal',
#  'sincerely',
#  'phillip',
#  'allen',
#  'trading',
#  'vision',
#  'meetinnymex',
#  'expiration',
#  'time',
#  'frame',
#  'reschedule',
#  'burnejeff',
#  'need',
#  'site',
#  'plan',
#  'burnet',
#  'remember',
#  'written',
#  'approval',
#  'brenda',
#  'stone',
#  'sell',
#  'property',
#  'concerns',
#  'property',
#  'subdivided',
#  'like',
#  'review',
#  'closing',
#  'statements',
#  'soon',
#  'possible',
#  'phillip',
#  'sept',
#  'paymenbrenda',
#  'checked',
#  'records',
#  'mailed',
#  'check',
#  'normal',
#  'august',
#  'mailed',
#  'pate',
#  'college',
#  'station',
#  'ahead',
#  'mail',
#  'check',
#  'shows',
#  'treat',
#  'payment',
#  'october',
#  'know',
#  'concerns',
#  'site',
#  'plan',
#  'proceed',
#  'getting',
#  'details',
#  'getting',
#  'approval',
#  'amortization',
#  'schedule',
#  'send',
#  'soon',
#  'phillip',
#  'survey',
#  'phillip',
#  'alle',
#  'chelsea',
#  'villajeff',
#  'received',
#  'rent',
#  'roll',
#  'going',
#  'marcos',
#  'weekend',
#  'booked',
#  'stage',
#  'coach',
#  'drive',
#  'friday',
#  'evening',
#  'know',
#  'week',
#  'need',
#  'inside',
#  'chelsea',
#  'villa',
#  'changed',
#  'hands',
#  'price',
#  'getting',
#  'look',
#  'site',
#  'plans',
#  'burnet',
#  'deal',
#  'remember',
#  'brenda',
#  'happy',
#  'phillip',
#  'curvwhy',
#  'aeco',
#  'basis',
#  'list',
#  'nwpl',
#  'mapped',
#  'differently',
#  'aeco',
#  'correlation',
#  'nymex',
#  'aeco',
#  'sagewood',
#  'etcjeff',
#  'clearly',
#  'receive',
#  'commission',
#  'deal',
#  'sagewood',
#  'surprised',
#  'request',
#  'payment',
#  'type',
#  'project',
#  'involved',
#  'creekside',
#  'business',
#  'brokering',
#  'properties',
#  'contacts',
#  'position',
#  'based',
#  'legal',
#  'perceive',
#  'ethical',
#  'issue',
#  'propose',
#  'look',
#  'developing',
#  'project',
#  'scratch',
#  'prepared',
#  'sagewood',
#  'phillip',
#  'urgent',
#  'print',
#  'reina',
#  'pull',
#  'tori',
#  'martin',
#  'cuilla',
#  'resumes',
#  'past',
#  'performance',
#  'reviews',
#  'reresumes',
#  'western',
#  'market',
#  'report',
#  'drafrichard',
#  'compare',
#  'california',
#  'production',
#  'numbers',
#  'california',
#  'report',
#  'shows',
#  'utilities',
#  'receive',
#  'survey',
#  'information',
#  'emai',
#  'subjectgreg',
#  'message',
#  'good',
#  'luck',
#  'bike',
#  'ride',
#  'apartment',
#  'setting',
#  'studio',
#  'kids',
#  'school',
#  'work',
#  'going',
#  'keith',
#  'security',
#  'request',
#  'clog',
#  'nnjez',
#  'deniedwhy',
#  'requests',
#  'coming',
#  'request',
#  'steve',
#  'keaalan',
#  'received',
#  'updated',
#  'numbers',
#  'keith',
#  'holst',
#  'receive',
#  'phillip',
#  'meeting',
#  'discuss',
#  'direct',
#  'expense',
#  'plansuzanne',
#  'details',
#  'email',
#  'plan',
#  'prior',
#  'meeting',
#  'need',
#  'provide',
#  'headcount',
#  'afternoon',
#  'week',
#  'fine',
#  'phillip',
#  'regulatory',
#  'filing',
#  'summarcolleen',
#  'mike',
#  'grigsby',
#  'distribution',
#  'note',
#  'idea',
#  'patti',
#  'holding',
#  'phillip',
#  'evaluation',
#  'trading',
#  'applicatiobruce',
#  'stop',
#  'reuters',
#  'phillip',
#  'receiptlucy',
#  'email',
#  'attachment',
#  'work',
#  'today',
#  'phillip',
#  'fileplan',
#  'project',
#  'needs',
#  'approvayou',
#  'approval',
#  'checkbook',
#  'budgelucy',
#  'discuss',
#  'email',
#  'later',
#  'progress',
#  'creating',
#  'spreadsheets',
#  'probably',
#  'need',
#  'close',
#  'file',
#  'attach',
#  'email',
#  'want',
#  'progress',
#  'files',
#  'phillip',
#  'request',
#  'steve',
#  'enron',
#  'close',
#  'checked',
#  'exercising',
#  'options',
#  'smith',
#  'barney',
#  'enron',
#  'kind',
#  'exclusive',
#  'paine',
#  'weber',
#  'starting',
#  'exercise',
#  'going',
#  'proceeds',
#  'apartment',
#  'complex',
#  'think',
#  'selling',
#  'jdsu',
#  'buying',
#  'sdli',
#  'look',
#  'play',
#  'rising',
#  'prices',
#  'thanks',
#  'phillip',
#  'tried',
#  'address',
#  'access',
#  'need',
#  'enter',
#  'domain',
#  'recooper',
#  'website',
#  'ectpdx',
#  'sunone',
#  'ctatham',
#  'navsetup',
#  'index',
#  'different',
#  'address',
#  'approval',
#  'grant',
#  'paul',
#  'requested',
#  'rights',
#  'thanks',
#  'phillip',
#  'request',
#  'steve',
#  'cash',
#  'hehub',
#  'chicago',
#  'pepl',
#  'katy',
#  'socal',
#  'opal',
#  'permian',
#  'daily',
#  'hehub',
#  'chicago',
#  'pepl',
#  'katy',
#  'socal',
#  'nwpl',
#  'permian',
#  'prompt',
#  'nymex',
#  'chicago',
#  'pepl',
#  'socal',
#  'nwpl',
#  'modei',
#  'tried',
#  'model',
#  'work',
#  'transportation',
#  'modecolleen',
#  'office',
#  'friday',
#  'keith',
#  'holst',
#  'attend',
#  'managing',
#  'transport',
#  'west',
#  'desk',
#  'phillip',
#  'approval',
#  'overdue',
#  'access',
#  'request',
#  'paul',
#  'lucci',
#  'enron',
#  'coina',
#  'times',
#  'think',
#  'jeff',
#  'wants',
#  'message',
#  'help',
#  'phillip',
#  'request',
#  'submitted',
#  'access',
#  'request',
#  'frank',
#  'ermis',
#  'enron',
#  'coina',
#  'getting',
#  'security',
#  'requests',
#  'approve',
#  'care',
#  'phillip',
#  'trading',
#  'skills',
#  'want',
#  'trading',
#  'desk',
#  'report',
#  'propertlucy',
#  'july',
#  'bank',
#  'statement',
#  'friday',
#  'refax',
#  'phillip',
#  'survey',
#  'information',
#  'email',
#  'outlook',
#  'migration',
#  'team',
#  'enron',
#  'cheryl',
#  'wilchynski',
#  'corp',
#  'enron',
#  'enron',
#  'cindy',
#  'ward',
#  'enron',
#  'enron',
#  'hill',
#  'corp',
#  'enron',
#  'enron',
#  'sonja',
#  'galloway',
#  'corp',
#  'enron',
#  'enron',
#  'bilal',
#  'bajwa',
#  'enron',
#  'enron',
#  'binh',
#  'pham',
#  'bradley',
#  'jones',
#  'enron',
#  'enronxgate',
#  'bruce',
#  'mills',
#  'corp',
#  'enron',
#  'enron',
#  'chance',
#  'rabon',
#  'enron',
#  'enronxgate',
#  'chuck',
#  'ames',
#  'enron',
#  'enron',
#  'david',
#  'baumbach',
#  'doan',
#  'enron',
#  'enronxgate',
#  'neal',
#  'free',
#  'phillip',
#  'love',
#  'sladana',
#  'anna',
#  'kulic',
#  'enron',
#  'enro',
#  'nxgate',
#  'victor',
#  'guggenheim',
#  'alejandra',
#  'chavez',
#  'enron',
#  'enron',
#  'bike',
#  'enron',
#  'enronxgate',
#  'carole',
#  'frank',
#  'enron',
#  'enron',
#  'darron',
#  'giron',
#  'elizabeth',
#  'hernandez',
#  'elizabeth',
#  'shim',
#  'corp',
#  'enron',
#  'enron',
#  'jeff',
#  'royed',
#  'corp',
#  'enron',
#  'enron',
#  'keiser',
#  'kimat',
#  'singla',
#  'kristen',
#  'clause',
#  'enron',
#  'enronxgate',
#  'kulvinder',
#  'fowler',
#  'enron',
#  'enron',
#  'kyle',
#  'lilly',
#  'luchas',
#  'johnson',
#  'enron',
#  'enron',
#  'maria',
#  'garza',
#  'patrick',
#  'ryder',
#  'enron',
#  'enron',
#  'ryan',
#  'rourke',
#  'enron',
#  'enronxgate',
#  'yuan',
#  'tian',
#  'enron',
#  'enron',
#  'frank',
#  'ermis',
#  'jane',
#  'tholt',
#  'reitm',
#  'eyer',
#  'keith',
#  'holst',
#  'matthew',
#  'lenhart',
#  'grigsby',
#  'monique',
#  'sanchez',
#  'phillip',
#  'allen',
#  'randall',
#  'tori',
#  'kuykendall',
#  'norman',
#  'jackie',
#  'travis',
#  'michael',
#  'gasper',
#  'brenda',
#  'fletcher',
#  'jeanne',
#  'wukasch',
#  'corp',
#  'enron',
#  'enron',
#  'mary',
#  'theresa',
#  'frank',
#  'mike',
#  'potter',
#  'enron',
#  'enron',
#  'natalie',
#  'baker',
#  'anne',
#  'calcagno',
#  'enron',
#  'enron',
#  'albert',
#  'stromquist',
#  'corp',
#  'enron',
#  'enron',
#  'rajesh',
#  'ettiar',
#  'derek',
#  'anderson',
#  'horn',
#  'camille',
#  'gerard',
#  'corp',
#  'enron',
#  'enron',
#  'cathy',
#  'lira',
#  'enron',
#  'daniel',
#  'castagnola',
#  'corp',
#  'enron',
#  'nguyen',
#  'enron',
#  'enron',
#  'andy',
#  'pace',
#  'enron',
#  'enron',
#  'anna',
#  'santuc',
#  'enron',
#  'enron',
#  'claudia',
#  'guerra',
#  'enron',
#  'enron',
#  'clayton',
#  'vernon',
#  'corp',
#  'enron',
#  'enron',
#  'david',
#  'ryan',
#  'corp',
#  'enron',
#  'enron',
#  'eric',
#  'smith',
#  'contractor',
#  'enron',
#  'communicat',
#  'ions',
#  'enron',
#  'communications',
#  'grace',
#  'enron',
#  'enron',
#  'jason',
#  'kaniss',
#  'enron',
#  'onxgate',
#  'kevin',
#  'cline',
#  'corp',
#  'enron',
#  'enron',
#  'rika',
#  'imai',
#  'enron',
#  'enron',
#  'todd',
#  'decoo',
#  'corp',
#  'enron',
#  'enron',
#  'beth',
#  'jensen',
#  'npng',
#  'enron',
#  'enron',
#  'billi',
#  'harrill',
#  'npng',
#  'enron',
#  'enron',
#  'martha',
#  'sumner',
#  'kenney',
#  'npng',
#  'enron',
#  'enron',
#  'phyllis',
#  'miller',
#  'npng',
#  'enron',
#  'sandy',
#  'olofson',
#  'npng',
#  'enron',
#  'enron',
#  'theresa',
#  'byrne',
#  'npng',
#  'enron',
#  'enron',
#  'danny',
#  'ccarty',
#  'enron',
#  'enron',
#  'denis',
#  'enron',
#  'enron',
#  'john',
#  'ayres',
#  'enron',
#  'nron',
#  'john',
#  'millar',
#  'enron',
#  'enron',
#  'julie',
#  'armstrong',
#  'corp',
#  'enron',
#  'enron',
#  'maggie',
#  'schroeder',
#  'enron',
#  'enron',
#  'brown',
#  'enron',
#  'enron',
#  'randy',
#  'cantrell',
#  'nron',
#  'enron',
#  'tracy',
#  'scott',
#  'corp',
#  'enron',
#  'enron',
#  'charles',
#  'muzzy',
#  'cora',
#  'pendergrass',
#  'corp',
#  'enron',
#  'enron',
#  'darren',
#  'espey',
#  'corp',
#  'enron',
#  'enron',
#  'jessica',
#  'white',
#  'enron',
#  'enron',
#  ...]

# %%
len(list_of_words)
# Out:
# 45513057

# %%
# Obtain the total number of unique words
total_words = len(list(set(list_of_words)))
total_words
# Out:
# 453539

# %%
# join the words into a string
df['clean_joined'] = df['clean_text'].apply(lambda x: " ".join(x))

# %%
df['clean_joined'][0]
# Out:
# 'retraveling business meeting takes trip especially prepare presentation suggest holding business plan meetings trip formal business meetings honest opinions trip desired necessary business meetings think productive stimulate discussions different groups working presenter speaks quiet waiting turn meetings better held round table discussion format suggestion austin play golf rent boat flying takes time'

# %% [markdown]
# ## Visualize cleaned up dataset

# %%
df
# Out:
#          index                                    message-id  \
# 0            1  <15464986.1075855378456.JavaMail.evans@thyme
# 1            2  <24216240.1075855687451.JavaMail.evans@thyme
# 2            4  <30922949.1075863688243.JavaMail.evans@thyme
# 3            5  <30965995.1075863688265.JavaMail.evans@thyme
# 4            7  <17189699.1075863688308.JavaMail.evans@thyme
# ...        ...                                           ...
# 451600  517392  <26807948.1075842029936.JavaMail.evans@thyme
# 451601  517393  <25835861.1075842029959.JavaMail.evans@thyme
# 451602  517394  <28979867.1075842029988.JavaMail.evans@thyme
# 451603  517395  <22052556.1075842030013.JavaMail.evans@thyme
# 451604  517396  <28618979.1075842030037.JavaMail.evans@thyme
#
#                           from                         to  \
# 0       phillip.allen@enron.co     john.lavorato@enron.co
# 1       phillip.allen@enron.co      leah.arsdall@enron.co
# 2       phillip.allen@enron.co        greg.piper@enron.co
# 3       phillip.allen@enron.co        greg.piper@enron.co
# 4       phillip.allen@enron.co    joyce.teixeira@enron.co
# ...                        ...                        ...
# 451600  john.zufferli@enron.co        kori.loibl@enron.co
# 451601  john.zufferli@enron.co     john.lavorato@enron.co
# 451602  john.zufferli@enron.co       dawn.doucet@enron.co
# 451603  john.zufferli@enron.co      jeanie.slone@enron.co
# 451604  john.zufferli@enron.co  livia_zufferli@monitor.co
#
#                                            completed_text  fraud  \
# 0       ReTraveling to have a business meeting takes t...      0
# 1                   Re: testest successful.  way to go!!!      0
# 2             Re: HellLet's shoot for Tuesday at 11:45.        0
# 3       Re: HellGreg,\n\n How about either next Tuesda...      0
# 4       Re: PRC review - phone callany morning between...      0
# ...                                                   ...    ...
# 451600  Trade with John LavoratThis is a trade with OI...      0
# 451601  Gas HedgeSome of my position is with the Alber...      0
# 451602  RE: CONFIDENTIA2\n\n -----Original Message----...      0
# 451603  Calgary Analyst/AssociatAnalyst\t\t\t\t\tRank\...      0
# 451604  RE: ali's essayi think the YMCA has a class th...      0
#
#                                                clean_text  \
# 0       [retraveling, business, meeting, takes, trip, ...
# 1                                   [testest, successful]
# 2                               [helllet, shoot, tuesday]
# 3                  [hellgreg, tuesday, thursday, phillip]
# 4                       [review, phone, callany, morning]
# ...                                                   ...
# 451600  [trade, john, lavoratthis, trade, spec, hedge,...
# 451601  [hedgesome, position, alberta, term, book, sen...
# 451602  [confidentia, original, message, doucet, dawn,...
# 451603  [calgary, analyst, associatanalyst, rank, step...
# 451604  [essayi, think, ymca, class, people, recoverin...
#
#                                              clean_joined
# 0       retraveling business meeting takes trip especi...
# 1                                      testest successful
# 2                                   helllet shoot tuesday
# 3                       hellgreg tuesday thursday phillip
# 4                            review phone callany morning
# ...                                                   ...
# 451600  trade john lavoratthis trade spec hedge john l...
# 451601  hedgesome position alberta term book send posi...
# 451602  confidentia original message doucet dawn sent ...
# 451603  calgary analyst associatanalyst rank stephane ...
# 451604  essayi think ymca class people recovering hear...
#
# [451605 rows x 8 columns]

# %%
# plot the word cloud for text that is considered "fraud"
plt.figure(figsize = (7,7)) 
wc = WordCloud(max_words = 2000 , width = 1920 , height = 1080 ,colormap='vlag', stopwords = stop_words).generate(" ".join(df[df.fraud == 1].clean_joined))
plt.imshow(wc, interpolation = 'bilinear')
plt.axis('off')
plt.tight_layout(pad=0)
plt.show()

# %%
# plot the word cloud for text that is considered "non-fraud"
plt.figure(figsize = (7,7)) 
wc = WordCloud(max_words = 2000 , width = 1920 , height = 1080 ,colormap='vlag', stopwords = stop_words).generate(" ".join(df[df.fraud == 0].clean_joined))
plt.imshow(wc, interpolation = 'bilinear')
plt.axis('off')
plt.tight_layout(pad=0)
plt.show()

# %%
# length of maximum document will be needed to create word embeddings 
maxlen = -1
for doc in df.clean_joined:
    tokens = nltk.word_tokenize(doc)
    if(maxlen<len(tokens)):
        maxlen = len(tokens)
print("The maximum number of words in any email is =", maxlen)
# Out:
# The maximum number of words in any email is = 75922

# %%
# visualize the distribution of number of words in an email.

plt.figure(figsize = (5, 5))
sns.histplot(x = [len(nltk.word_tokenize(x)) for x in df.clean_joined], color='#366f88', bins = 100)
plt.show()

# %% [markdown]
# ## Prepare the data by perfoming tokenization and padding

# %% [markdown]
# Tokenizer allows us to vectorize text corpus by turning each text into a sequence of integers

# %%
X=df['clean_joined']
y=df['fraud']

# %%
# split data into test and train 

X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.3, random_state=42)

# %%
# Create a tokenizer to tokenize the words and create sequences of tokenized words
tokenizer = Tokenizer(num_words = total_words)
tokenizer.fit_on_texts(X_train)
train_sequences = tokenizer.texts_to_sequences(X_train)
test_sequences = tokenizer.texts_to_sequences(X_test)

# %%
print("The encoding for document:\n",df.clean_joined[0],"\n is : ",train_sequences[0])
# Out:
# The encoding for document:
#  retraveling business meeting takes trip especially prepare presentation suggest holding business plan meetings trip formal business meetings honest opinions trip desired necessary business meetings think productive stimulate discussions different groups working presenter speaks quiet waiting turn meetings better held round table discussion format suggestion austin play golf rent boat flying takes time
#  is :  [158, 1414, 9908, 958, 14, 794, 104, 1040, 243, 2232, 1796, 1901, 385, 794, 1244, 149, 364, 2850, 149, 84, 2333, 442, 2070, 1377, 1946, 2467, 3791, 675, 4044, 1377, 940, 772, 1881, 472, 2234, 888, 151, 936, 1881, 472, 1414, 63, 1909, 305, 794, 23, 754, 1025, 145, 1414, 46, 23, 23, 1414, 597, 835, 1028, 201, 6, 835, 185, 1028, 201, 6, 7387, 5875, 3761, 1414, 36, 1021, 893, 1028, 201, 6, 1646, 3375, 1028, 201, 6, 9544, 3375, 1028, 201, 6, 9545, 1646, 893, 1028, 201, 6, 1646, 893, 1028, 201, 6, 1646, 893, 1028, 201, 6, 1646, 893, 1028, 201, 6, 11317, 893, 1028, 201, 6, 3215, 1887, 1028, 201, 6, 8490, 893, 1887, 1028, 201, 6, 8491, 835, 199, 893, 1887, 1028, 201, 6, 8363, 153, 16918, 1881, 472, 6092, 824, 877]

# %%
# Add padding can either be maxlen = 4406 or smaller number maxlen = 40 seems to work well based on results
padded_train = pad_sequences(train_sequences,maxlen = 40, padding = 'post', truncating = 'post')
padded_test = pad_sequences(test_sequences,maxlen = 40, truncating = 'post')

# %%
for i,doc in enumerate(padded_train[:1]):
     print("The padded encoding for document",i+1," is : ",doc)
# Out:
# The padded encoding for document 1  is :  [ 158 1414 9908  958   14  794  104 1040  243 2232 1796 1901  385  794
#  1244  149  364 2850  149   84 2333  442 2070 1377 1946 2467 3791  675
#  4044 1377  940  772 1881  472 2234  888  151  936 1881  472]

# %% [markdown]
# ## Built the model

# %%
model= RandomForestClassifier(random_state=42, n_estimators=10, max_depth=None)

# embeddidng layer


result=model.fit(X_train, y_train)
y_pred=result.predict(X_test)


print("Classification report for the test set")
print(classification_report(y_test,y_pred))

print('Confusion matrix')
print(confusion_matrix(y_test,y_pred))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [39], in <cell line: 6>()
#       1 model= RandomForestClassifier(random_state=42, n_estimators=10, max_depth=None)
#       3 # embeddidng layer
# ----> 6 result=model.fit(X_train, y_train)
#       7 y_pred=result.predict(X_test)
#      10 print("Classification report for the test set")
#
# File ~\anaconda3\envs\Da_Env1\lib\site-packages\sklearn\ensemble\_forest.py:331, in BaseForest.fit(self, X, y, sample_weight)
#     329 if issparse(y):
#     330     raise ValueError("sparse multilabel-indicator for y is not supported.")
# --> 331 X, y = self._validate_data(
#     332     X, y, multi_output=True, accept_sparse="csc", dtype=DTYPE
#     333 )
#     334 if sample_weight is not None:
#     335     sample_weight = _check_sample_weight(sample_weight, X)
#
# File ~\anaconda3\envs\Da_Env1\lib\site-packages\sklearn\base.py:596, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, **check_params)
#     594         y = check_array(y, input_name="y", **check_y_params)
#     595     else:
# --> 596         X, y = check_X_y(X, y, **check_params)
#     597     out = X, y
#     599 if not no_val_X and check_params.get("ensure_2d", True):
#
# File ~\anaconda3\envs\Da_Env1\lib\site-packages\sklearn\utils\validation.py:1074, in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#    1069         estimator_name = _check_estimator_name(estimator)
#    1070     raise ValueError(
#    1071         f"{estimator_name} requires y to be passed, but the target y is None"
#    1072     )
# -> 1074 X = check_array(
#    1075     X,
#    1076     accept_sparse=accept_sparse,
#    1077     accept_large_sparse=accept_large_sparse,
#    1078     dtype=dtype,
#    1079     order=order,
#    1080     copy=copy,
#    1081     force_all_finite=force_all_finite,
#    1082     ensure_2d=ensure_2d,
#    1083     allow_nd=allow_nd,
#    1084     ensure_min_samples=ensure_min_samples,
#    1085     ensure_min_features=ensure_min_features,
#    1086     estimator=estimator,
#    1087     input_name="X",
#    1088 )
#    1090 y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric, estimator=estimator)
#    1092 check_consistent_length(X, y)
#
# File ~\anaconda3\envs\Da_Env1\lib\site-packages\sklearn\utils\validation.py:856, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     854         array = array.astype(dtype, casting="unsafe", copy=False)
#     855     else:
# --> 856         array = np.asarray(array, order=order, dtype=dtype)
#     857 except ComplexWarning as complex_warning:
#     858     raise ValueError(
#     859         "Complex data not supported\n{}\n".format(array)
#     860     ) from complex_warning
#
# File ~\anaconda3\envs\Da_Env1\lib\site-packages\pandas\core\series.py:872, in Series.__array__(self, dtype)
#     825 def __array__(self, dtype: npt.DTypeLike | None = None) -> np.ndarray:
#     826     """
#     827     Return the values as a NumPy array.
#     828
#    (...)
#     870           dtype='datetime64[ns]')
#     871     """
# --> 872     return np.asarray(self._values, dtype)
#
# ValueError: could not convert string to float: 'daily charts matrices links information contained based sources believe reliable represent accurate complete contained considered offer sell solicitation offer financial instruments discussed opinions expressed solely author differ material respects expressed published behalf carr futures officers directors employees affiliates carr futures charts available clicking link contained email reason unable receive charts contact email email charts attachments crude carrfut research energy crude natural carrfut research energy ngas distillate unleaded charts today brent spread carrfut research energy heat crack carrfut research energy heatcrack crack carrfut research energy gascrack heat spread carrfut research energy heat spread carrfut research energy heat spread carrfut research energy heat spread carrfut research energy unlead spread carrfut research energy strip matrix carrfut research energy stripmatrixng spread matrix carrfut research energy spreadmatrixng crude products spread matrix carrfut research energy spreadmatrixcl scott oblander carr futures wacker suite chicago'
